# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruf089/Competitive-Programming/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step-1: install the package

# %%
# !pip install pycryptodome
# Out:
# ...
#      |████████████████████████████████| 13.7MB 292kB/s
# ...

# %% [markdown]
# Step 2 : Test the Library was installed properly or not

# %%
# !python -m Crypto.SelfTest
# Out:
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...
